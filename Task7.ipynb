# %% [markdown]
# #Venkatalakshmi Bandaru
# #gripjune21
# # Task8 -Time analysis-covid19

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv("owid-covid-data.csv")

# %%
df.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.498
# 1      AFG      Asia  ...           64.83                   0.498
# 2      AFG      Asia  ...           64.83                   0.498
# 3      AFG      Asia  ...           64.83                   0.498
# 4      AFG      Asia  ...           64.83                   0.498
#
# [5 rows x 50 columns]

# %%
df.describe()
# Out:
#         total_cases      new_cases  ...  life_expectancy  human_development_index
# count  4.573100e+04   53335.000000  ...     52787.000000             51817.000000
# mean   9.510545e+04     926.380763  ...        72.894834                 0.710991
# std    4.831549e+05    4636.677162  ...         7.750961                 0.155149
# min    1.000000e+00  -10034.000000  ...        53.280000                 0.354000
# 25%    3.900000e+02       0.000000  ...        67.130000                 0.590000
# 50%    4.229000e+03      15.000000  ...        74.470000                 0.741000
# 75%    3.753450e+04     261.500000  ...        78.570000                 0.838000
# max    9.796744e+06  125414.000000  ...        86.750000                 0.953000
#
# [8 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53433 entries, 0 to 53432
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            53110 non-null  object
#  1   continent                           53110 non-null  object
#  2   location                            53433 non-null  object
#  3   date                                53433 non-null  object
#  4   total_cases                         45731 non-null  float64
#  5   new_cases                           53335 non-null  float64
#  6   new_cases_smoothed                  52505 non-null  float64
#  7   total_deaths                        39042 non-null  float64
#  8   new_deaths                          53335 non-null  float64
#  9   new_deaths_smoothed                 52505 non-null  float64
#  10  total_cases_per_million             45423 non-null  float64
#  11  new_cases_per_million               53012 non-null  float64
#  12  new_cases_smoothed_per_million      52187 non-null  float64
#  13  total_deaths_per_million            38747 non-null  float64
#  14  new_deaths_per_million              53012 non-null  float64
#  15  new_deaths_smoothed_per_million     52187 non-null  float64
#  16  reproduction_rate                   35776 non-null  float64
#  17  icu_patients                        4312 non-null   float64
#  18  icu_patients_per_million            4312 non-null   float64
#  19  hosp_patients                       5256 non-null   float64
#  20  hosp_patients_per_million           5256 non-null   float64
#  21  weekly_icu_admissions               430 non-null    float64
#  22  weekly_icu_admissions_per_million   430 non-null    float64
#  23  weekly_hosp_admissions              688 non-null    float64
#  24  weekly_hosp_admissions_per_million  688 non-null    float64
#  25  new_tests                           21187 non-null  float64
#  26  total_tests                         21014 non-null  float64
#  27  total_tests_per_thousand            21014 non-null  float64
#  28  new_tests_per_thousand              21187 non-null  float64
#  29  new_tests_smoothed                  23811 non-null  float64
#  30  new_tests_smoothed_per_thousand     23811 non-null  float64
#  31  positive_rate                       22114 non-null  float64
#  32  tests_per_case                      21594 non-null  float64
#  33  tests_units                         24752 non-null  object
#  34  stringency_index                    46394 non-null  float64
#  35  population                          53110 non-null  float64
#  36  population_density                  52787 non-null  float64
#  37  median_age                          50526 non-null  float64
#  38  aged_65_older                       50526 non-null  float64
#  39  aged_70_older                       50203 non-null  float64
#  40  gdp_per_capita                      51495 non-null  float64
#  41  extreme_poverty                     34264 non-null  float64
#  42  cardiovasc_death_rate               51424 non-null  float64
#  43  diabetes_prevalence                 52787 non-null  float64
#  44  female_smokers                      39796 non-null  float64
#  45  male_smokers                        39150 non-null  float64
#  46  handwashing_facilities              25862 non-null  float64
#  47  hospital_beds_per_thousand          46579 non-null  float64
#  48  life_expectancy                     52787 non-null  float64
#  49  human_development_index             51817 non-null  float64
# dtypes: float64(45), object(5)
# memory usage: 20.4+ MB

# %%
df.shape
# Out:
# (53433, 50)

# %%
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 50)

# %%
df.count()
# Out:
# iso_code                              53110
# continent                             53110
# location                              53433
# date                                  53433
# total_cases                           45731
# new_cases                             53335
# new_cases_smoothed                    52505
# total_deaths                          39042
# new_deaths                            53335
# new_deaths_smoothed                   52505
# total_cases_per_million               45423
# new_cases_per_million                 53012
# new_cases_smoothed_per_million        52187
# total_deaths_per_million              38747
# new_deaths_per_million                53012
# new_deaths_smoothed_per_million       52187
# reproduction_rate                     35776
# icu_patients                           4312
# icu_patients_per_million               4312
# hosp_patients                          5256
# hosp_patients_per_million              5256
# weekly_icu_admissions                   430
# weekly_icu_admissions_per_million       430
# weekly_hosp_admissions                  688
# weekly_hosp_admissions_per_million      688
# new_tests                             21187
# total_tests                           21014
# total_tests_per_thousand              21014
# new_tests_per_thousand                21187
# new_tests_smoothed                    23811
# new_tests_smoothed_per_thousand       23811
# positive_rate                         22114
# tests_per_case                        21594
# tests_units                           24752
# stringency_index                      46394
# population                            53110
# population_density                    52787
# median_age                            50526
# aged_65_older                         50526
# aged_70_older                         50203
# gdp_per_capita                        51495
# extreme_poverty                       34264
# cardiovasc_death_rate                 51424
# diabetes_prevalence                   52787
# female_smokers                        39796
# male_smokers                          39150
# handwashing_facilities                25862
# hospital_beds_per_thousand            46579
# life_expectancy                       52787
# human_development_index               51817
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# iso_code                                323
# continent                               323
# location                                  0
# date                                      0
# total_cases                            7702
# new_cases                                98
# new_cases_smoothed                      928
# total_deaths                          14391
# new_deaths                               98
# new_deaths_smoothed                     928
# total_cases_per_million                8010
# new_cases_per_million                   421
# new_cases_smoothed_per_million         1246
# total_deaths_per_million              14686
# new_deaths_per_million                  421
# new_deaths_smoothed_per_million        1246
# reproduction_rate                     17657
# icu_patients                          49121
# icu_patients_per_million              49121
# hosp_patients                         48177
# hosp_patients_per_million             48177
# weekly_icu_admissions                 53003
# weekly_icu_admissions_per_million     53003
# weekly_hosp_admissions                52745
# weekly_hosp_admissions_per_million    52745
# new_tests                             32246
# total_tests                           32419
# total_tests_per_thousand              32419
# new_tests_per_thousand                32246
# new_tests_smoothed                    29622
# new_tests_smoothed_per_thousand       29622
# positive_rate                         31319
# tests_per_case                        31839
# tests_units                           28681
# stringency_index                       7039
# population                              323
# population_density                      646
# median_age                             2907
# aged_65_older                          2907
# aged_70_older                          3230
# gdp_per_capita                         1938
# extreme_poverty                       19169
# cardiovasc_death_rate                  2009
# diabetes_prevalence                     646
# female_smokers                        13637
# male_smokers                          14283
# handwashing_facilities                27571
# hospital_beds_per_thousand             6854
# life_expectancy                         646
# human_development_index                1616
# dtype: int64

# %%
df1 = df[["date", "total_cases", "new_cases", "total_deaths", "new_tests", "total_tests"]]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2020-01-23          NaN        0.0           NaN        NaN          NaN
# 1  2020-01-24          NaN        0.0           NaN        NaN          NaN
# 2  2020-01-25          NaN        0.0           NaN        NaN          NaN
# 3  2020-01-26          NaN        0.0           NaN        NaN          NaN
# 4  2020-01-27          NaN        0.0           NaN        NaN          NaN

# %%
df1.date = pd.to_datetime(df.date)
df1.set_index('date', inplace = True)
df1.head()
df1.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2020-02-27          8.0        7.0           NaN      279.0       1226.0
# 2020-02-28          8.0        0.0           NaN      449.0       1675.0
# 2020-02-29         18.0       10.0           NaN      257.0       1932.0
# 2020-03-01         27.0        9.0           NaN      372.0       2304.0
# 2020-03-02         42.0       15.0           NaN      478.0       2782.0

# %%
df1.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
plt.title("covid data analysis ",fontsize=20)
# Out:
# Text(0.5, 1.0, 'covid data analysis ')

# %%
df1.total_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
plt.title("Total number of cases ",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total number of cases ')

# %%
df1.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
plt.title("Total number of deaths ",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total number of deaths ')

# %%
df1.new_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
plt.title("Total number of new cases are occured ",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total number of new cases are occured ')

# %%
df1.total_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
plt.title("Total number of tests done",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total number of tests done')

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);
plt.title("Total number of cases ",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total number of cases ')

# %%
new_cases = df1[['new_cases']]
new_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);
plt.title("Total number of new cases ",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total number of new cases ')

# %%
total_deaths = df1[['total_deaths']]
total_deaths.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);
plt.title("Total number of deaths ",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total number of deaths ')

# %%
new_tests = df1[['new_tests']]
new_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);
plt.title("Total number of new tests",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total number of new tests')

# %%
total_tests = df1[['total_tests']]
total_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);
